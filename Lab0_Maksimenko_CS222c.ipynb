# %% [markdown]
# # Лабораторна робота №0
# # Тема: Основи роботи в середовищі Jupyter Notebook
#
# <br>
#
# <div style="background-color: white;">
# Виконав: студент групи КН - 222c Максименко Валентин Михайлович
# </div>
# <div style="background-color: white;">
# Перевірив: асистент кафедри Герман Олександрович Зверцев
# </div>
#
# # Мета роботи
#
# Ознайомитись з особливістями використання мови Python в середовищі Jupyter Notebook та отримати навички роботи з блокнотом.
#
# ## 1.Завдання
#
# <br>
#
# <div style="background-color: white; padding: 10px;">
# **Примітка:**
# </div>
# <div style="background-color: white; padding: 10px;">
# Щоб вибрати номер варіанта, запустіть оператор
# </div>
# <div style="background-color: white; padding: 10px;">
# N = ord("X") % 10 + 1,
# </div>
# <div style="background-color: white; padding: 10px;">
# де X – перша велика літера вашого імені в латинській транскрипції.
# </div>
#
# 1. Встановити Jupyter Notebook. Доступні варіанти для вибору: 1, 2, 3.
# 2. Налаштувати робочу папку.
# 3. За допомогою мови Markdown та HTML тегів для країни, відповідно до свого номеру варіанту (див. табл. 1), ввести інформацію щодо площини, населення, державного устрою, видатних персоналій, пам’яток культури та природи тощо. При оформленні інформації повинні бути використані:
#
# - Заголовки різних рівнів;
# - Різні види накреслення символів (курсив, напівжирний тощо);
# - Символи різних кольорів;
# - Рамки навколо тексту;
# - Таблиці;
# - Вкладені списки;
# - Картинки за допомогою посилань та вбудовані;
# - Гіперпосилання
# - За допомогою HTML тегу `<svg>` намалювати флаг країни.
#
# 4. Створити функцію для реалізації алгоритму, відповідно до номеру свого варіанту з табл. 1. Для створеної функції реалізувати 2-3 тестові приклади в комірках ноутбуку. Для всіх варіантів організувати контроль значень, що вводяться, наприклад:
#
# ![image-4.png](attachment:image-4.png)
#
# Таблиця 1. Завдання до виконання роботи
# ![image-3.png](attachment:image-3.png)
#
# 5. Завантажити отриманий файл на GitHub

# %%
N = ord('V') % 10 + 1
print(N)
# Out:
# 7

# %%
def decimal_to_binary(number):
    
    if isinstance(number, int):
        if number == 0:
            return '0'
        binary = ''
        is_negative = False
        if number < 0:
            is_negative = True
            number = abs(number)
        while number > 0:
            remainder = number % 2
            binary = str(remainder) + binary
            number //= 2
        if is_negative:
            return '1|' + binary
        return '0|' + binary
    
    elif isinstance(number, float):
        integer_part = abs(int(number))
        decimal_part = abs(number) - integer_part
        integer_binary = decimal_to_binary(integer_part)
        decimal_binary = ''
        precision = 6
        for _ in range(precision):
            decimal_part *= 2
            if int(decimal_part) == 1:
                decimal_binary += '1'
                decimal_part -= int(decimal_part)
            else:
                decimal_binary += '0'
        return integer_binary + '.' + decimal_binary.rstrip('0')

print(decimal_to_binary(32))    # Виведе: 0|100000
print(decimal_to_binary(-10.25))  # Виведе: 1|1010.01
# Out:
# 0|100000
# 0|1010.01

# %% [markdown]
# # Ісландія
#
# ![Флаг Ісландії](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_Iceland.svg/1920px-Flag_of_Iceland.svg.png)
#
# ## Загальна інформація
# *Ісландія - країна, розташована в Північній Атлантиці. Це вулканічний острів з унікальною природою та багатою культурною спадщиною.*
#
# ### Площа
# **Площа Ісландії становить приблизно 103,000 квадратних кілометрів.**
#
# ### Населення
# <span style="color: blue;"> Ісландія має приблизно 356,991 жителів. </span>
#
# ## Державний устрій
# <br>
# <div style="border: 2px solid black; padding: 10px;">
# Ісландія є парламентською демократією. Президент є главою держави, а Прем'єр-міністр - главою уряду.
# </div>
#
# ## Видатні персоналії
# - Лагардейр Йоханнессон - президент Ісландії.
# - Халдор Лакснесс - відомий письменник і поет.
# - Бьорк Гудмундсдоттір - відома музикантка та співачка.
#
# ## Пам'ятки культури
# Ісландія славиться своєю культурною спадщиною, включаючи:
# - Геотермальні джерела
# - Флудір та інші ландшафти країни
# - Саги - традиційні ісландські літературні твори
#
# ## Природа
# Ісландія відома своєю красою природи, включаючи:
# - Гори та вулкани
# - Фьорди та льодовики
# - Гарячі джерела та гейзери
#
# [Докладніше про Ісландію](https://uk.wikipedia.org/wiki/%D0%86%D1%81%D0%BB%D0%B0%D0%BD%D0%B4%D1%96%D1%8F)
#
# <table>
#   <tr>
#     <th>Мова</th>
#     <th>Валюта</th>
#     <th>Часовий пояс</th>
#   </tr>
#   <tr>
#     <td>Ісландська</td>
#     <td>Ісландська крона (ISK)</td>
#     <td>UTC±0</td>
#   </tr>
# </table>

# %% [markdown]
# ### Висновки:
#
# Під час виконання лабораторної роботи ми ознайомилися з основами роботи в середовищі Jupyter Notebook, встановили його на локальному комп'ютері, налаштували робочу папку та вивчили можливості роботи з мовою Markdown та HTML тегами для оформлення тексту. Крім того, була реалізована функція для переведення чисел з десяткової системи числення в двійкову з використанням мови Python.
